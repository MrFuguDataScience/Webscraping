# %% [markdown]
# # <font color=red>**Mr Fugu Data Science**</font>
#
# # `Indeed Webscraping Href (Job Description)- June 2022`
#
# # (◕‿◕✿)
#
# (Viewer submission help!)

# %%
# import os
import requests
from bs4 import BeautifulSoup # webscrape
from collections import defaultdict # default dictionary: store a list with each key
import pandas as pd     # DF
import re               # regular expressions
import datetime         # format date/time

# %% [markdown]
# # `Check my video webscrape Indeed June 2022:`
#
# https://youtu.be/-SjrfjKJqqI

# %%
# this was used for the person contacting me who had these details for their system
headers = {
    "User-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36"}

# Skills & Place of Work
skill = input('Enter your Skill: ').strip()
place = input('Enter the location: ').strip()
no_of_pages = int(input('Enter the # of pages to scrape: '))

indeed_posts=[]

for page in range(no_of_pages):
    # connecting to India Indeed
        url = 'https://www.indeed.co.in/jobs?q=' + skill + \
            '&l=' + place + '&sort=date' +'&start='+ str(page * 10)
        
        response = requests.get(url, headers=headers)
        html = response.text

        # Scrapping the Web (you can use 'html' or 'lxml')
        soup = BeautifulSoup(html, 'lxml')

        # Outer Most Entry Point of HTML:
        outer_most_point=soup.find('div',attrs={'id': 'mosaic-provider-jobcards'})
        
        # "UL" lists where the data are stored:
        
        for i in outer_most_point.find('ul'):
            
        # Job Title:
        
            job_title=i.find('h2',{'class':'jobTitle jobTitle-color-purple jobTitle-newJob'})
#             print(job_title)
            if job_title != None:
                jobs=job_title.find('a').text

        # Company Name:
    
            if i.find('span',{'class':'companyName'}) != None:
                company=i.find('span',{'class':'companyName'}).text   
                
        # Links: these Href links will take us to full job description
        
            if i.find('a') != None:
                links=i.find('a',{'class':'jcs-JobTitle'})['href']
                
        # Salary if available:
        
            if i.find('div',{'class':'attribute_snippet'}) != None:
                salary=i.find('div',{'class':'attribute_snippet'}).text

            else:
                salary='No Salary'

        # Job Post Date:

            if i.find('span', attrs={'class': 'date'}) != None:
                post_date = i.find('span', attrs={'class': 'date'}).text

        # Put everything together in a list of lists for the default dictionary
                        
            indeed_posts.append([company,jobs,links,salary, post_date])
            
            
# put together in list

# (create a dictionary with keys and a list of values from above "indeed_posts")

indeed_dict_list=defaultdict(list)

# Fields for our DF 

indeed_spec=['Company','job','link','Salary','Job_Posted_Date']
# Out:
# Enter your Skill: data analyst
# Enter the location: Chennai, Tamil Nadu
# Enter the # of pages to scrape: 2

# %%
print('These Href links will go to a new page containing full job description')
print('\n')
print(pd.DataFrame(indeed_posts,columns=indeed_spec)['link'][0]) 
#these are not the same, probably from recruiter(s)
print(pd.DataFrame(indeed_posts,columns=indeed_spec)['link'][1])

pd.DataFrame(indeed_posts,columns=indeed_spec)
# Out:
# These Href links will go to a new page containing full job description
#
#
# /rc/clk?jk=304a79fe6704a0f8&fccid=fe2d21eef233e94a&vjs=3
# /rc/clk?jk=ddd45abaa49f78f4&fccid=5249cd8e17163cb5&vjs=3
#                             Company  \
# 0                 ADCI - BLR 14 SEZ
# 1                Standard Chartered
# 2                Standard Chartered
# 3                               SGK
# 4                       AstraZeneca
# 5                       AstraZeneca
# 6    Alpha Net Technologies Pvt Ltd
# 7                              Citi
# 8                              Citi
# 9                              Citi
# 10                       Freshworks
# 11                       Freshworks
# 12                       FENG GROUP
# 13                            Shell
# 14                 Société Générale
# 15                            Shell
# 16                 Société Générale
# 17                 Société Générale
# 18                             Citi
# 19                   FLSmidth, Inc.
# 20                      BNP Paribas
# 21                             Flex
# 22                             Citi
# 23                             Citi
# 24                   Thryve Digital
# 25                         Barclays
# 26               Standard Chartered
# 27               Standard Chartered
# 28  Rapid Global Business Solutions
# 29  Rapid Global Business Solutions
# 30                 CIEL HR Services
# 31                       Prodapt SA
# 32                       CloudSense
# 33                       Prodapt SA
# 34    Ford Global Business Services
# 35    Ford Global Business Services
#
#                                                   job  \
# 0                        Business Research Analyst II
# 1                                       Analyst, FCSO
# 2                                             Analyst
# 3                       Sr Analyst - Business Systems
# 4                                          HR Analyst
# 5                                          HR Analyst
# 6     Database Developer/Analyst - Permanent Remote -
# 7                    C09 Data/Information Mgt Analyst
# 8   GFT Data Services - Business Analyst - Chennai...
# 9                                    Business analyst
# 10                                  Financial Analyst
# 11                                  Financial Analyst
# 12                     Data Modeling Analyst (Senior)
# 13                        CP Analyst - Materials Data
# 14  Sr. Analyst / Analyst – Hardware Asset Management
# 15                           R and A Business Analyst
# 16                     Regulatory Reporting - Analyst
# 17                     Regulatory Reporting - Analyst
# 18                   Business analyst - CTS - Chennai
# 19                                Master Data Analyst
# 20                                   Business Analyst
# 21            Senior Analyst - Master Data Management
# 22                         Operational Risk Analyst I
# 23                         Operational Risk Analyst I
# 24                 Process Analyst - Voice Services -
# 25                                   Business Analyst
# 26                                       Analyst-FSCO
# 27                                     Senior Analyst
# 28                            Data Analyst (Power BI)
# 29                            Data Analyst (Power BI)
# 30                       CIEL/SEL/26864: Data Analyst
# 31                                 Data Visualization
# 32                                  Reporting Analyst
# 33                             Data Modelling Analyst
# 34                             Eu PFM Pricing Analyst
# 35                             Eu PFM Pricing Analyst
#
#                                                  link  \
# 0   /rc/clk?jk=304a79fe6704a0f8&fccid=fe2d21eef233...
# 1   /rc/clk?jk=ddd45abaa49f78f4&fccid=5249cd8e1716...
# 2   /rc/clk?jk=430c49060bc64dcb&fccid=5249cd8e1716...
# 3   /rc/clk?jk=233badb0060a759e&fccid=8e3b99526c94...
# 4   /rc/clk?jk=dc6fd96efcb3f7ab&fccid=003656df63ce...
# 5   /rc/clk?jk=dc6fd96efcb3f7ab&fccid=003656df63ce...
# 6   /company/Alpha-Net-Technologies-Pvt-Ltd/jobs/D...
# 7   /rc/clk?jk=0184e0910a999784&fccid=5bcd1ef0a7f4...
# 8   /rc/clk?jk=58014c127a2b2127&fccid=5bcd1ef0a7f4...
# 9   /rc/clk?jk=c2d6fbe14c9e24c5&fccid=5bcd1ef0a7f4...
# 10  /rc/clk?jk=117c4d6f7eddcebc&fccid=37f39930e85b...
# 11  /rc/clk?jk=117c4d6f7eddcebc&fccid=37f39930e85b...
# 12  /rc/clk?jk=8f4a8159e4d0ad32&fccid=dd616958bd9d...
# 13  /rc/clk?jk=b0bf4ffd49a12a18&fccid=167aa4ca2fe7...
# 14  /rc/clk?jk=4f492f4d7934ae32&fccid=df6948c9b8da...
# 15  /rc/clk?jk=3b4e2e3f708f0612&fccid=167aa4ca2fe7...
# 16  /rc/clk?jk=5009b85d08449a78&fccid=df6948c9b8da...
# 17  /rc/clk?jk=5009b85d08449a78&fccid=df6948c9b8da...
# 18  /rc/clk?jk=73729a9f146166ed&fccid=5bcd1ef0a7f4...
# 19  /rc/clk?jk=830cb00736f4eba2&fccid=8cc6bea405b1...
# 20  /rc/clk?jk=e59a45aed3b4fdda&fccid=1392500f835b...
# 21  /rc/clk?jk=63ed036617ded666&fccid=b4ab9735c58e...
# 22  /rc/clk?jk=91c0c638410fcc95&fccid=5bcd1ef0a7f4...
# 23  /rc/clk?jk=91c0c638410fcc95&fccid=5bcd1ef0a7f4...
# 24  /rc/clk?jk=39711c839276bd9d&fccid=2616efa92eb7...
# 25  /rc/clk?jk=f71f03152eb4c4a0&fccid=057abf3fd357...
# 26  /rc/clk?jk=ade20c00d78bde3d&fccid=5249cd8e1716...
# 27  /rc/clk?jk=00343dbc99e1ca4a&fccid=5249cd8e1716...
# 28  /rc/clk?jk=da92dfdc653f21e2&fccid=ecfea27496c2...
# 29  /rc/clk?jk=da92dfdc653f21e2&fccid=ecfea27496c2...
# 30  /rc/clk?jk=e52196197b1eee98&fccid=2b1e42f645ee...
# 31  /rc/clk?jk=632d78dab0428297&fccid=32fe91ba0784...
# 32  /rc/clk?jk=eadb397336bf9425&fccid=1ef47986d846...
# 33  /rc/clk?jk=fd23a4deabf3e321&fccid=32fe91ba0784...
# 34  /rc/clk?jk=90d72135c4196e47&fccid=35c29eb190cc...
# 35  /rc/clk?jk=90d72135c4196e47&fccid=35c29eb190cc...
#
#                         Salary    Job_Posted_Date
# 0                    No Salary  PostedJust posted
# 1                    No Salary        PostedToday
# 2                    No Salary        PostedToday
# 3                    No Salary        PostedToday
# 4                    No Salary        PostedToday
# 5                    No Salary        PostedToday
# 6             ₹7,00,000 a year        PostedToday
# 7                    No Salary        PostedToday
# 8                    No Salary        PostedToday
# 9                    No Salary        PostedToday
# 10                   No Salary        PostedToday
# 11                   No Salary        PostedToday
# 12                   No Salary        PostedToday
# 13                   No Salary        PostedToday
# 14                   No Salary        PostedToday
# 15                   No Salary        PostedToday
# 16                   No Salary        PostedToday
# 17                   No Salary        PostedToday
# 18                   Full-time    Posted1 day ago
# 19                   Full-time    Posted1 day ago
# 20                   Full-time    Posted1 day ago
# 21                   Full-time    Posted1 day ago
# 22                   Full-time    Posted1 day ago
# 23                   No Salary    Posted1 day ago
# 24                   No Salary    Posted1 day ago
# 25                   No Salary    Posted1 day ago
# 26                   Full-time    Posted1 day ago
# 27                   Full-time    Posted1 day ago
# 28                   Full-time    Posted1 day ago
# 29                   No Salary    Posted1 day ago
# 30                   No Salary    Posted1 day ago
# 31                   Full-time   Posted2 days ago
# 32                   No Salary   Posted2 days ago
# 33  ₹50,000 - ₹2,50,000 a year   Posted2 days ago
# 34                   No Salary   Posted3 days ago
# 35                   No Salary   Posted3 days ago

# %% [markdown]
# # We have to take these links
#
# + These links will provide us with a popup page. The new page that will open will allow us to scrape anything. In our case it is beneficial to grab the job description for each posting in order to use this for NLP later featuring NLTK.
